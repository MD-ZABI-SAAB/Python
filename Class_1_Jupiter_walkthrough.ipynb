# %% [markdown]
# # what is a programming language ?
#
# - A way to communicate with machines (ex : c , c++ , java , pyhton)

# %% [markdown]
# # There are 2 types of programming language
#
# - HLL (High Level Language)
#
#   1. user friendly (simple english)
#   2. ex :- java, c++ , python
#
#
#  * LLL (Low Level Language)
#   1. system friendly (written in form of binary)
#   2. ex :- assembly languages

# %%
a = 20 # HLL

1100001 # LLL
# Out:
# 1100001

# %% [raw]
# "character ----> ascii value ----> Binary"
#
# # lets take an asci value 97
#
# # a ---> 97 ---> (1100001)
#
# 2  97  1
# 2  48  0
# 2  24  0
# 2  12  0
# 2  6   0
# 2  3   1
#    1
#
# '''continue divideing it by 2 until you get 0 or 1 in the remainder and take all the last values of every line ( IN REVERSE ORDER )
# for example here all the last values are (1100001)'''
#
# # This is how it works in the backend

# %%
ascii(0b1100001)
# Out:
# '97'

# %%
bin(97)
# Out:
# '0b1100001'

# %%
chr(97)
# Out:
# 'a'

# %% [markdown]
# # HLL IS FURTHER CLASSIFIED INTO
#
# A. COMPILER :- If there is a huge code it gets compiled and converted into binary and executed in one single shot.
#    - Faster
#    - Difficult to debug
#    - eg : c , c++ , java
#
# B. INTERPRETOR :- The code is converted and executed line by line.
#    - Slower
#    - Easier to debug
#    - eg : python

# %% [markdown]
# # Why Python ?
#  - Easy syntax
#  - It support a lot of libraries

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
a = 10
b = 20

print(a + b)
# Out:
# 30

# %% [markdown]
# # There are 2 main types of cell
#
# 1. coding cell :- You can only write a python code (ex = above cell)
#
# 2. Markdown cell :- You can write anything "it willl be considerd as text" (ex = current or below cell)

# %% [markdown]
# "once we add a # in front of a text in a markdown cell it will change font size which can also be considerd as heading and sub-heading"
#
# # Hello
#
# ## hello
#
# ### hello

# %%
"Convert a cell into markdown to create a heading (# <center> HEllO EVERYONE <center>)"

# <center> HELLO EVERYONE <center>
# Out:
# 'Convert a cell into markdown to create a heading (# <center> HEllO EVERYONE <center>)'

# %% [markdown]
# # <center> HELLO EVERYONE <center>

# %% [markdown]
# In markdown cell we can create points and bulletin points as well
#
# points( 1. )
# bulletin points ( - , * )
#
# 1. xxx
# - xxx
# * xxx
